# %%
import pandas as pd

# %%
data=pd.read_csv(r'C:\Users\ELCOT\Downloads\weather_data.csv')

# %%
data
# Out:
#        Precipitation      Full  Month  Week of  Year        City Code  \
# 0               0.00  1/3/2016      1        3  2016  Birmingham  BHM
# 1               0.00  1/3/2016      1        3  2016  Huntsville  HSV
# 2               0.16  1/3/2016      1        3  2016      Mobile  MOB
# 3               0.00  1/3/2016      1        3  2016  Montgomery  MGM
# 4               0.01  1/3/2016      1        3  2016   Anchorage  ANC
# ...              ...       ...    ...      ...   ...         ...  ...
# 16738           0.08  1/1/2017      1        1  2017      Casper  CPR
# 16739           0.00  1/1/2017      1        1  2017    Cheyenne  CYS
# 16740           0.00  1/1/2017      1        1  2017      Lander  LND
# 16741           0.06  1/1/2017      1        1  2017     Rawlins  RWL
# 16742           0.10  1/1/2017      1        1  2017    Sheridan  SHR
#
#              Location    State  Temperature_Avg Temp  Temperature_Max Temp  \
# ...

# %%
data.head(50)
# Out:
#     Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                 0.00  2016-01-03           1             3       2016
# 1                 0.00  2016-01-03           1             3       2016
# 2                 0.16  2016-01-03           1             3       2016
# 3                 0.00  2016-01-03           1             3       2016
# 4                 0.01  2016-01-03           1             3       2016
# 5                 0.09  2016-01-03           1             3       2016
# 6                 0.05  2016-01-03           1             3       2016
# 7                 0.15  2016-01-03           1             3       2016
# 8                 0.60  2016-01-03           1             3       2016
# 9                 2.15  2016-01-03           1             3       2016
# 10                0.00  2016-01-03           1             3       2016
# 11                0.00  2016-01-03           1             3       2016
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16743 entries, 0 to 16742
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Data.Precipitation         16743 non-null  float64
#  1   Date.Full                  16743 non-null  object
#  2   Date.Month                 16743 non-null  int64
#  3   Date.Week of               16743 non-null  int64
#  4   Date.Year                  16743 non-null  int64
#  5   Station.City               16743 non-null  object
#  6   Station.Code               16743 non-null  object
#  7   Station.Location           16743 non-null  object
#  8   Station.State              16743 non-null  object
#  9   Data.Temperature.Avg Temp  16743 non-null  int64
#  10  Data.Temperature.Max Temp  16743 non-null  int64
#  11  Data.Temperature.Min Temp  16743 non-null  int64
#  12  Data.Wind.Direction        16743 non-null  int64
# ...

# %%
data.shape
# Out:
# (16743, 14)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=16743, step=1)

# %%
data.columns
# Out:
# Index(['Data.Precipitation', 'Date.Full', 'Date.Month', 'Date.Week of',
#        'Date.Year', 'Station.City', 'Station.Code', 'Station.Location',
#        'Station.State', 'Data.Temperature.Avg Temp',
#        'Data.Temperature.Max Temp', 'Data.Temperature.Min Temp',
#        'Data.Wind.Direction', 'Data.Wind.Speed'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Precipitation           float64
# Full                     object
# Month                     int64
# Week of                   int64
# Year                      int64
# City                     object
# Code                     object
# Location                 object
# State                    object
# Temperature_Avg Temp      int64
# Temperature_Max Temp      int64
# Temperature_Min Temp      int64
# Wind_Direction            int64
# Wind_Speed              float64
# dtype: object

# %%
data['Date.Full'].unique()
# Out:
# array(['2016-01-03', '2016-01-10', '2016-01-17', '2016-01-24',
#        '2016-01-31', '2016-02-07', '2016-02-14', '2016-02-21',
#        '2016-02-28', '2016-03-06', '2016-03-13', '2016-03-20',
#        '2016-03-27', '2016-04-03', '2016-04-10', '2016-04-17',
#        '2016-04-24', '2016-05-01', '2016-05-08', '2016-05-15',
#        '2016-05-22', '2016-05-29', '2016-06-05', '2016-06-12',
#        '2016-06-19', '2016-06-26', '2016-07-03', '2016-07-10',
#        '2016-07-17', '2016-07-24', '2016-07-31', '2016-08-07',
#        '2016-08-14', '2016-08-21', '2016-08-28', '2016-09-04',
#        '2016-09-11', '2016-09-18', '2016-09-25', '2016-10-02',
#        '2016-10-09', '2016-10-16', '2016-10-23', '2016-10-30',
#        '2016-11-06', '2016-11-13', '2016-11-20', '2016-11-27',
#        '2016-12-04', '2016-12-11', '2016-12-18', '2016-12-25',
#        '2017-01-01'], dtype=object)

# %%
data['Wind_Speed'].nunique()
# Out:
# 1461

# %%
data['Wind_Speed'].count()
# Out:
# 16743

# %%
data['Temperature_Avg Temp']
# Out:
# 0        39
# 1        39
# 2        46
# 3        45
# 4        34
#          ..
# 16738    23
# 16739    32
# 16740    17
# 16741    23
# 16742    21
# Name: Temperature_Avg Temp, Length: 16743, dtype: int64

# %%
data['Month'].value_counts()
# Out:
# 1     1892
# 10    1585
# 5     1585
# 7     1572
# 12    1268
# 8     1268
# 9     1265
# 4     1265
# 6     1262
# 3     1262
# 2     1260
# 11    1259
# Name: Month, dtype: int64

# %%
data['Month'].value_counts()[2]
# Out:
# 1260

# %%
d1 = (data['Month'] == 2).sum()
d1
# Out:
# 1260

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16743 entries, 0 to 16742
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Data.Precipitation         16743 non-null  float64
#  1   Date.Full                  16743 non-null  object
#  2   Date.Month                 16743 non-null  int64
#  3   Date.Week of               16743 non-null  int64
#  4   Date.Year                  16743 non-null  int64
#  5   Station.City               16743 non-null  object
#  6   Station.Code               16743 non-null  object
#  7   Station.Location           16743 non-null  object
#  8   Station.State              16743 non-null  object
#  9   Data.Temperature.Avg Temp  16743 non-null  int64
#  10  Data.Temperature.Max Temp  16743 non-null  int64
#  11  Data.Temperature.Min Temp  16743 non-null  int64
#  12  Data.Wind.Direction        16743 non-null  int64
# ...

# %% [markdown]
# # Find all the unique ' Data.Wind.Speed' value in the data.

# %%
data.nunique()
# Out:
# Data.Precipitation            565
# Date.Full                      53
# Date.Month                     12
# Date.Week of                   31
# Date.Year                       2
# Station.City                  307
# Station.Code                  318
# Station.Location              318
# Station.State                  53
# Data.Temperature.Avg Temp     119
# Data.Temperature.Max Temp     125
# Data.Temperature.Min Temp     114
# Data.Wind.Direction            37
# Data.Wind.Speed              1461
# dtype: int64

# %%
data['Wind_Speed'].nunique()
# Out:
# 1461

# %%
data['Wind_Speed'].unique() #Answer
# Out:
# array([ 4.33,  3.86,  9.73, ..., 12.53, 19.98, 18.16])

# %%
#Group by
maximum=data.groupby(['State'])['Temperature_Avg Temp'].sum()
max_temp_state=maximum[maximum==maximum.max()]
max_temp_state
# Out:
# State
# Texas    86727
# Name: Temperature_Avg Temp, dtype: int64

# %%
result = data.groupby(['State'])['Temperature_Avg Temp'].sum()
max_row = result[result == result.max()]
print(max_row)

# %% [markdown]
# # Find the number of times when the State in Alabama

# %%
data.head(2)
# Out:
#    Precipitation      Full  Month  Week of  Year        City Code  \
# 0            0.0  1/3/2016      1        3  2016  Birmingham  BHM
# 1            0.0  1/3/2016      1        3  2016  Huntsville  HSV
#
#          Location    State  Temperature_Avg Temp  Temperature_Max Temp  \
# 0  Birmingham, AL  Alabama                    39                    46
# 1  Huntsville, AL  Alabama                    39                    47
#
#    Temperature_Min Temp  Wind_Direction  Wind_Speed
# 0                    32              33        4.33
# 1                    31              32        3.86

# %%
data.State.value_counts()
# Out:
# Alaska            1719
# Texas             1272
# California         999
# Florida            636
# Montana            583
# Michigan           477
# Nebraska           424
# New York           424
# Oregon             424
# Tennessee          420
# Pennsylvania       371
# Mississippi        371
# North Carolina     371
# Ohio               371
# Washington         371
# Missouri           371
# Virginia           318
# Illinois           318
# Georgia            318
# Colorado           318
# Kansas             318
# Nevada             318
# Iowa               265
# Hawaii             265
# Kentucky           265
# Minnesota          265
# Wyoming            265
# North Dakota       265
# Arizona            265
# South Dakota       265
# Louisiana          261
# South Carolina     212
# Indiana            212
# Alabama            212
# West Virginia      212
# Oklahoma           212
# Wisconsin          212
# Arkansas           159
# New Mexico         159
# Idaho              159
# ...

# %%
#Filtering
#data.head(2)
data[data.State=="Alabama"]
# Out:
#        Precipitation        Full  Month  Week of  Year        City Code  \
# 0               0.00    1/3/2016      1        3  2016  Birmingham  BHM
# 1               0.00    1/3/2016      1        3  2016  Huntsville  HSV
# 2               0.16    1/3/2016      1        3  2016      Mobile  MOB
# 3               0.00    1/3/2016      1        3  2016  Montgomery  MGM
# 315             0.52   1/10/2016      1       10  2016  Birmingham  BHM
# ...              ...         ...    ...      ...   ...         ...  ...
# 16112           0.00  12/25/2016     12       25  2016  Montgomery  MGM
# 16426           0.51    1/1/2017      1        1  2017  Birmingham  BHM
# 16427           1.57    1/1/2017      1        1  2017  Huntsville  HSV
# 16428           1.72    1/1/2017      1        1  2017      Mobile  MOB
# 16429           0.62    1/1/2017      1        1  2017  Montgomery  MGM
#
#              Location    State  Temperature_Avg Temp  Temperature_Max Temp  \
# ...

# %%
#Groupby
data.groupby('State').get_group('Alabama')
# Out:
#        Precipitation        Full  Month  Week of  Year        City Code  \
# 0               0.00    1/3/2016      1        3  2016  Birmingham  BHM
# 1               0.00    1/3/2016      1        3  2016  Huntsville  HSV
# 2               0.16    1/3/2016      1        3  2016      Mobile  MOB
# 3               0.00    1/3/2016      1        3  2016  Montgomery  MGM
# 315             0.52   1/10/2016      1       10  2016  Birmingham  BHM
# ...              ...         ...    ...      ...   ...         ...  ...
# 16112           0.00  12/25/2016     12       25  2016  Montgomery  MGM
# 16426           0.51    1/1/2017      1        1  2017  Birmingham  BHM
# 16427           1.57    1/1/2017      1        1  2017  Huntsville  HSV
# 16428           1.72    1/1/2017      1        1  2017      Mobile  MOB
# 16429           0.62    1/1/2017      1        1  2017  Montgomery  MGM
#
#              Location    State  Temperature_Avg Temp  Temperature_Max Temp  \
# ...

# %% [markdown]
# # Find the number of times when the 'wind speed' was exctly 4km/h

# %%
data[data['Wind_Speed']==4]
# Out:
#        Precipitation        Full  Month  Week of  Year            City Code  \
# 232             0.01    1/3/2016      1        3  2016       Pendleton  PDT
# 531             0.05   1/10/2016      1       10  2016       Williston  ISN
# 1155            0.96   1/24/2016      1       24  2016  Raleigh/Durham  RDU
# 2572            0.06   2/28/2016      2       28  2016       Red Bluff  RBL
# 2648            1.68   2/28/2016      2       28  2016         Slidell  ASD
# 4331            0.00    4/3/2016      4        3  2016       Pendleton  PDT
# 5307            0.22   4/24/2016      4       24  2016       Nashville  BNA
# 5515            0.00    5/1/2016      5        1  2016      Greenville  GLH
# 6000            0.10   5/15/2016      5       15  2016       Anchorage  ANC
# 6297            0.04   5/15/2016      5       15  2016         Seattle  SEA
# 6335            0.56   5/22/2016      5       22  2016        Mc Grath  MCG
# ...

# %% [markdown]
# # Find out all the NUll Values in the data.

# %%
data.isnull().sum()
# Out:
# Precipitation           0
# Full                    0
# Month                   0
# Week of                 0
# Year                    0
# City                    0
# Code                    0
# Location                0
# State                   0
# Temperature_Avg Temp    0
# Temperature_Max Temp    0
# Temperature_Min Temp    0
# Wind_Direction          0
# Wind_Speed              0
# dtype: int64

# %%
data[data.isnull()]
# Out:
#        Precipitation Full  Month  Week of  Year City Code Location State  \
# 0                NaN  NaN    NaN      NaN   NaN  NaN  NaN      NaN   NaN
# 1                NaN  NaN    NaN      NaN   NaN  NaN  NaN      NaN   NaN
# 2                NaN  NaN    NaN      NaN   NaN  NaN  NaN      NaN   NaN
# 3                NaN  NaN    NaN      NaN   NaN  NaN  NaN      NaN   NaN
# 4                NaN  NaN    NaN      NaN   NaN  NaN  NaN      NaN   NaN
# ...              ...  ...    ...      ...   ...  ...  ...      ...   ...
# 16738            NaN  NaN    NaN      NaN   NaN  NaN  NaN      NaN   NaN
# 16739            NaN  NaN    NaN      NaN   NaN  NaN  NaN      NaN   NaN
# 16740            NaN  NaN    NaN      NaN   NaN  NaN  NaN      NaN   NaN
# 16741            NaN  NaN    NaN      NaN   NaN  NaN  NaN      NaN   NaN
# 16742            NaN  NaN    NaN      NaN   NaN  NaN  NaN      NaN   NaN
#
#        Temperature_Avg Temp  Temperature_Max Temp  Temperature_Min Temp  \
# ...

# %%
data.notnull().sum()
# Out:
# Precipitation           16743
# Full                    16743
# Month                   16743
# Week of                 16743
# Year                    16743
# City                    16743
# Code                    16743
# Location                16743
# State                   16743
# Temperature_Avg Temp    16743
# Temperature_Max Temp    16743
# Temperature_Min Temp    16743
# Wind_Direction          16743
# Wind_Speed              16743
# dtype: int64

# %% [markdown]
# # Rename the column name "Full" of the dataframe to "Date"''

# %%
data.head(2)
# Out:
#    Precipitation      Full  Month  Week of  Year        City Code  \
# 0            0.0  1/3/2016      1        3  2016  Birmingham  BHM
# 1            0.0  1/3/2016      1        3  2016  Huntsville  HSV
#
#          Location    State  Temperature_Avg Temp  Temperature_Max Temp  \
# 0  Birmingham, AL  Alabama                    39                    46
# 1  Huntsville, AL  Alabama                    39                    47
#
#    Temperature_Min Temp  Wind_Direction  Wind_Speed
# 0                    32              33        4.33
# 1                    31              32        3.86

# %%
data.rename(columns={'Full':'Date'},inplace=True)

# %%
data
# Out:
#        Precipitation      Date  Month  Week of  Year        City Code  \
# 0               0.00  1/3/2016      1        3  2016  Birmingham  BHM
# 1               0.00  1/3/2016      1        3  2016  Huntsville  HSV
# 2               0.16  1/3/2016      1        3  2016      Mobile  MOB
# 3               0.00  1/3/2016      1        3  2016  Montgomery  MGM
# 4               0.01  1/3/2016      1        3  2016   Anchorage  ANC
# ...              ...       ...    ...      ...   ...         ...  ...
# 16738           0.08  1/1/2017      1        1  2017      Casper  CPR
# 16739           0.00  1/1/2017      1        1  2017    Cheyenne  CYS
# 16740           0.00  1/1/2017      1        1  2017      Lander  LND
# 16741           0.06  1/1/2017      1        1  2017     Rawlins  RWL
# 16742           0.10  1/1/2017      1        1  2017    Sheridan  SHR
#
#              Location    State  Temperature_Avg Temp  Temperature_Max Temp  \
# ...

# %% [markdown]
# # What is the mean 'Wind Speed'

# %%
data['Wind_Speed'].mean()
# Out:
# 6.3298202233769825

# %% [markdown]
# # What is the standard deviation of Wind Speed in this data

# %%
data.Wind_Speed.std()
# Out:
# 3.4947852525194727

# %% [markdown]
# # what is the variance of Wind_Speed in this data

# %%
data.Wind_Speed.var()
# Out:
# 12.213523961227596

# %%
data
# Out:
#        Precipitation      Date  Month  Week of  Year        City Code  \
# 0               0.00  1/3/2016      1        3  2016  Birmingham  BHM
# 1               0.00  1/3/2016      1        3  2016  Huntsville  HSV
# 2               0.16  1/3/2016      1        3  2016      Mobile  MOB
# 3               0.00  1/3/2016      1        3  2016  Montgomery  MGM
# 4               0.01  1/3/2016      1        3  2016   Anchorage  ANC
# ...              ...       ...    ...      ...   ...         ...  ...
# 16738           0.08  1/1/2017      1        1  2017      Casper  CPR
# 16739           0.00  1/1/2017      1        1  2017    Cheyenne  CYS
# 16740           0.00  1/1/2017      1        1  2017      Lander  LND
# 16741           0.06  1/1/2017      1        1  2017     Rawlins  RWL
# 16742           0.10  1/1/2017      1        1  2017    Sheridan  SHR
#
#              Location    State  Temperature_Avg Temp  Temperature_Max Temp  \
# ...

# %% [markdown]
# # Find all instance when 'wind speed' is above 24 and 'Precipitation' is above 0.05

# %%
data[(data['Wind_Speed']>24)&(data['Precipitation']>2)]
# Out:
#        Precipitation        Date  Month  Week of  Year            City Code  \
# 10291           3.79   8/14/2016      8       14  2016  Mt. Washington  MWN
# 10608           2.10   8/21/2016      8       21  2016  Mt. Washington  MWN
# 15351           2.43   12/4/2016     12        4  2016  Mt. Washington  MWN
# 15985           2.42  12/18/2016     12       18  2016  Mt. Washington  MWN
# 16619           2.71    1/1/2017      1        1  2017  Mt. Washington  MWN
#
#                  Location          State  Temperature_Avg Temp  \
# 10291  Mt. Washington, NH  New Hampshire                    54
# 10608  Mt. Washington, NH  New Hampshire                    50
# 15351  Mt. Washington, NH  New Hampshire                    17
# 15985  Mt. Washington, NH  New Hampshire                     2
# 16619  Mt. Washington, NH  New Hampshire                    11
#
#        Temperature_Max Temp  Temperature_Min Temp  Wind_Direction  Wind_Speed
# ...

# %% [markdown]
# # what is the mean value of each column against each State

# %%
 data.groupby('State').mean()
# Out:
#                 Precipitation     Month    Week of         Year  \
# State
# Alabama              0.776179  6.339623  15.660377  2016.018868
# Alaska               0.566126  6.392670  15.603839  2016.019779
# Arizona              0.162566  6.339623  15.660377  2016.018868
# Arkansas             0.603711  6.339623  15.660377  2016.018868
# California           0.323774  6.308308  15.666667  2016.018018
# Colorado             0.182987  6.339623  15.660377  2016.018868
# Connecticut          0.587830  6.339623  15.660377  2016.018868
# DE                   0.632453  6.339623  15.660377  2016.018868
# Delaware             0.632453  6.339623  15.660377  2016.018868
# Florida              0.891006  6.339623  15.660377  2016.018868
# Georgia              0.712799  6.339623  15.660377  2016.018868
# Hawaii               0.664868  6.339623  15.660377  2016.018868
# Idaho                0.238113  6.339623  15.660377  2016.018868
# ...

# %% [markdown]
# # What is the  minimum and maximum value of each column against each state

# %%
data.groupby('State').min()
# Out:
#                 Precipitation      Date  Month  Week of  Year  \
# State
# Alabama                  0.00  1/1/2017      1        1  2016
# Alaska                   0.00  1/1/2017      1        1  2016
# Arizona                  0.00  1/1/2017      1        1  2016
# Arkansas                 0.00  1/1/2017      1        1  2016
# California               0.00  1/1/2017      1        1  2016
# Colorado                 0.00  1/1/2017      1        1  2016
# Connecticut              0.00  1/1/2017      1        1  2016
# DE                       0.00  1/1/2017      1        1  2016
# Delaware                 0.00  1/1/2017      1        1  2016
# Florida                  0.00  1/1/2017      1        1  2016
# Georgia                  0.00  1/1/2017      1        1  2016
# Hawaii                   0.00  1/1/2017      1        1  2016
# Idaho                    0.00  1/1/2017      1        1  2016
# Illinois                 0.00  1/1/2017      1        1  2016
# ...

# %%
data.groupby('State').max()
# Out:
#                 Precipitation      Date  Month  Week of  Year  \
# State
# Alabama                  4.44  9/4/2016     12       31  2017
# Alaska                  10.34  9/4/2016     12       31  2017
# Arizona                  2.28  9/4/2016     12       31  2017
# Arkansas                 6.08  9/4/2016     12       31  2017
# California               6.60  9/4/2016     12       31  2017
# Colorado                 1.82  9/4/2016     12       31  2017
# Connecticut              2.81  9/4/2016     12       31  2017
# DE                       3.27  9/4/2016     12       31  2017
# Delaware                 3.27  9/4/2016     12       31  2017
# Florida                 15.19  9/4/2016     12       31  2017
# Georgia                 11.52  9/4/2016     12       31  2017
# Hawaii                  14.03  9/4/2016     12       31  2017
# Idaho                    1.74  9/4/2016     12       31  2017
# Illinois                 5.59  9/4/2016     12       31  2017
# ...

# %% [markdown]
# # Find all instances when:
# #State is Virginia and Temperature_Max Temp is greater than 50
# #or
# #Wind_Speed is above 40

# %%
data[(data['State']=='Virginia') & (data['Temperature_Max Temp']>50) | (data['Wind_Speed']>40)].head(40)
# Out:
#       Precipitation       Date  Month  Week of  Year            City Code  \
# 191            0.00   1/3/2016      1        3  2016  Mt. Washington  MWN
# 290            0.00   1/3/2016      1        3  2016         Norfolk  ORF
# 291            0.00   1/3/2016      1        3  2016        Richmond  RIC
# 821            0.00  1/17/2016      1       17  2016  Mt. Washington  MWN
# 920            1.59  1/17/2016      1       17  2016         Norfolk  ORF
# 1550           0.03  1/31/2016      1       31  2016         Norfolk  ORF
# 1553           0.01  1/31/2016      1       31  2016  Wallops Island  WAL
# 1766           0.00   2/7/2016      2        7  2016  Mt. Washington  MWN
# 1865           4.19   2/7/2016      2        7  2016         Norfolk  ORF
# 1866           1.31   2/7/2016      2        7  2016        Richmond  RIC
# 1868           2.29   2/7/2016      2        7  2016  Wallops Island  WAL
# 1869           0.68   2/7/2016      2        7  2016      Washington  DCA
# ...

# %%
class ZeroDenominatorError(Exception):
    try:
        a = int(input('enter'))
        b = int(input("enter"))
        if(b==0):
            raise ZeroDivisionError() 
        c = a/b
        print(c)
    except vd:
        print('Zero Division Error occured')

z = ZeroDenominatorError()
# Out:
# enter9
# enter
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-e8f910231404> in ZeroDenominatorError()
#       3         a = int(input('enter'))
# ----> 4         b = int(input("enter"))
#       5         if(b==0):
#
# ValueError: invalid literal for int() with base 10: ''
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-e8f910231404> in <module>
# ----> 1 class ZeroDenominatorError(Exception):
#       2     try:
#       3         a = int(input('enter'))
#       4         b = int(input("enter"))
#       5         if(b==0):
#
# <ipython-input-33-e8f910231404> in ZeroDenominatorError()
#       7         c = a/b
#       8         print(c)
# ----> 9     except vd:
#      10         print('Zero Division Error occured')
#      11
#
# ...

# %%
class ZeroDenominatorError(Exception):
    # Custom exception class for zero denominator error
    pass

def divide(a, b):
    try:
        if b == 0:
            raise ZeroDenominatorError("Cannot divide by zero!")
        return a / b
    except ZeroDenominatorError as e:
        print(f"Error: {e}")

# Example usage:
divide(10, 7)
# Out:
# 1.4285714285714286

# %%
class ZeroDenominatorError(Exception):
    # You can add additional attributes or methods if needed
    pass

def divide(a, b):
    if b == 0:
        raise ZeroDenominatorError("Cannot divide by zero!")
    return a / b

try:
    result = divide(10, j)
except ZeroDenominatorError as e:
    print(f"Error: {e}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-0cb7ebc4c596> in <module>
#       9
#      10 try:
# ---> 11     result = divide(10, j)
#      12 except ZeroDenominatorError as e:
#      13     print(f"Error: {e}")
#
# NameError: name 'j' is not defined
